# %% [markdown]
# # Pandas Exercise

# %% [markdown]
# Exercise 1: Write a Pandas program to create and
# display a DataFrame from a specified dictionary data which has the index labels.

# %% [markdown]
# exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
#         'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
#         'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# %% [markdown]
#        name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
import pandas as pd

# %%
index = {'a','b','c','d','e','f','g','h','i','j'}
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, 'NaN', 9, 20, 14.5, 'NaN', 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df = pd.DataFrame(exam_data,index)
df
# Out:
#         name score  attempts qualify
# e  Anastasia  12.5         1     yes
# f       Dima     9         3      no
# d  Katherine  16.5         2     yes
# c      James   NaN         3      no
# a      Emily     9         2      no
# g    Michael    20         3     yes
# b    Matthew  14.5         1     yes
# h      Laura   NaN         1      no
# i      Kevin     8         2      no
# j      Jonas    19         1     yes

# %% [markdown]
# Exercise 2: Write a Pandas program to select the rows where number of attempts in the
# examination is less than 2 and score greater than 15.

# %% [markdown]
# Number of attempts in the examination is less than 2 and score greater than 15 :
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
index = {'a','b','c','d','e','f','g','h','i','j'}
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, 0, 9, 20, 14.5, 0, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df = pd.DataFrame(exam_data,index)
df1 = df.loc[((df['attempts']<2) & (df['score']>15))]
df1
# Out:
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %% [markdown]
# Exerise 3: Change the value in row 'd' to 11.5

# %% [markdown]
# Original data frame:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
#
# Change the score in row 'd' to 11.5:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.at['f','score']=11.5
df
# Out:
#         name  score  attempts qualify
# e  Anastasia   12.5         1     yes
# f       Dima   11.5         3      no
# d  Katherine   16.5         2     yes
# c      James    0.0         3      no
# a      Emily    9.0         2      no
# g    Michael   20.0         3     yes
# b    Matthew   14.5         1     yes
# h      Laura    0.0         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# Exercise 4: Write a Pandas program to calculate the sum of the examination attempts by the students.
# data: d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}

# %% [markdown]
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# Rows for colum1 value == 4
#    col1  col2  col3
# 1     4     5     8
# 3     4     7     0

# %%
data = {'col1': [1, 4, 3, 4, 5], 
        'col2': [4, 5, 6, 7, 8], 
        'col3': [7, 8, 9, 0, 1]}
dfr = pd.DataFrame(data)
dfr1 = dfr[dfr['col1'] == 4]
dfr1
# Out:
#    col1  col2  col3
# 1     4     5     8
# 3     4     7     0

# %% [markdown]
# Exercise 5: Drop a list of rows from a specified DataFrame
# data:
# d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}

# %% [markdown]
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# New DataFrame after removing 2nd & 4th rows:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 3     4     7     0

# %%
data = {'col1': [1, 4, 3, 4, 5], 
        'col2': [4, 5, 6, 7, 8], 
        'col3': [7, 8, 9, 0, 1]}
dfr = pd.DataFrame(data)
print("Original Data Frame:")
dfr
# Out:
# Original Data Frame:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
todel = [2,4]
print("New Dataframe after removing 2nd and 4th rows:")
dfr.drop(dfr.index[todel])
# Out:
# New Dataframe after removing 2nd and 4th rows:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 3     4     7     0

# %% [markdown]
# Exercise 6: Check whether a given column is present in a DataFrame or not
# data:
# d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}

# %% [markdown]
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# Col4 is not present in DataFrame.
# Col1 is present in DataFrame.

# %%
data = {'col1': [1, 2, 3, 4, 7], 
        'col2': [4, 5, 6, 9, 5], 
        'col3': [7, 8, 12, 1, 11]}
dframe = pd.DataFrame(data)
print("Original DataFrame")
dframe
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %%
ip = input("Enter a column:")
if ip in dframe:
        print(ip,"is present in DataFrame.")
else:
        print(ip,"is not present in DataFrame.")
# Out:
# Enter a column:col5
# col5 is not present in DataFrame.

# %% [markdown]
# Exercise 7: Get column index from column name of a given DataFrame
# data:
# d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}
# HINT: Try using a function called get_loc():
# Syntax: dataframe.columns.get_loc()

# %% [markdown]
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
#
# Index of 'col2'
# 1

# %%
data = {'col1': [1, 2, 3, 4, 7], 
        'col2': [4, 5, 6, 9, 5], 
        'col3': [7, 8, 12, 1, 11]}
dframe1 = pd.DataFrame(data)
print("Original DataFrame")
dframe1
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %%
print("Index of 'col2':")
print(dframe1.columns.get_loc("col2"))
# Out:
# Index of 'col2':
# 1

# %% [markdown]
# Exercise 8: Write a Pandas program to select all columns, except one given column in a DataFrame.

# %% [markdown]
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
#
# All columns except 'col3':
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5

# %%
data = {'col1': [1, 2, 3, 4, 7], 
        'col2': [4, 5, 6, 9, 5], 
        'col3': [7, 8, 12, 1, 11]}
dframe = pd.DataFrame(data)
print("Original DataFrame")
dframe
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %%
#lists that particular column in index 0 and 1
print("All columns except'col3':")
dframe.iloc[:,[0,1]]
# Out:
# All columns except'col3':
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5

# %% [markdown]
# Exercise 9: Write a Pandas program to remove last n rows of a given DataFrame.

# %% [markdown]
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11
#
# After removing last 3 rows of the said DataFrame:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8

# %%
data = {'col1': [1, 2, 3, 4, 7, 11], 
        'col2': [4, 5, 6, 9, 5, 0], 
        'col3': [7, 5, 8, 12, 1, 11]}
dfram1 = pd.DataFrame(data)
print("Original DataFrame")
dfram1
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11

# %%
dfrl = dfram1.iloc[:3]
print("After removing last 3 rows of the said DataFrame:")
dfrl
# Out:
# After removing last 3 rows of the said DataFrame:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8

# %% [markdown]
# Exercise 10: Display the movies longer than 30 minutes and shorter than 360 minutes

# %% [markdown]
# List of movies longer than 30 minutes and shorter than 360 minutes:
#                                        Title  Runtime (Minutes)
# 0                    Guardians of the Galaxy                121
# 1                                 Prometheus                124
# 2                                      Split                117
# 3                                       Sing                108
# 4                              Suicide Squad                123
# 5                             The Great Wall                103
# 6                                 La La Land                128
# 7                                   Mindhorn                 89
# 8                         The Lost City of Z                141
# 9                                 Passengers                116
# 10   Fantastic Beasts and Where to Find Them                133
# 11                            Hidden Figures                127
# 12                                 Rogue One                133
# 13                                     Moana                107
# 14                                  Colossal                109
# 15                   The Secret Life of Pets                 87
# 16                             Hacksaw Ridge                139
# 17                              Jason Bourne                123
# 18                                      Lion                118
# 19                                   Arrival                116
# 20                                      Gold                120
# 21                     Manchester by the Sea                137
# 22                            Hounds of Love                108
# 23                                    Trolls                 92
# 24              Independence Day: Resurgence                120
# 25                           Paris pieds nus                 83
# 26                   Bahubali: The Beginning                159
# 27                                Dead Awake                 99
# 28                                  Bad Moms                100
# 29                          Assassin's Creed                115
# ..                                       ...                ...
# 970                        Texas Chainsaw 3D                 92
# 971                                Disturbia                105
# 972                             Rock of Ages                123
# 973                                 Scream 4                111
# 974                           Queen of Katwe                124
# 975               My Big Fat Greek Wedding 2                 94
# 976                              Dark Places                113
# 977                            Amateur Night                 92
# 978           It's Only the End of the World                 97
# 979                       The Skin I Live In                120
# 980                     Miracles from Heaven                109
# 981                                    Annie                118
# 982                      Across the Universe                133
# 983                            Let's Be Cops                104
# 984                                      Max                111
# 985                            Your Highness                102
# 986                      Final Destination 5                 92
# 987                             Endless Love                104
# 988                                  Martyrs                 99
# 989                                    Selma                128
# 990           Underworld: Rise of the Lycans                 92
# 991                         Taare Zameen Par                165
# 992                     Take Me Home Tonight                 97
# 993                 Resident Evil: Afterlife                 97
# 994                                Project X                 88
# 995                     Secret in Their Eyes                111
# 996                          Hostel: Part II                 94
# 997                   Step Up 2: The Streets                 98
# 998                             Search Party                 93
# 999                               Nine Lives                 87
#
# [1000 rows x 2 columns]

# %%
mv = pd.read_csv("IMDB-Movie-Data-Exercise.csv",index_col='Title')
mv
# Out:
#                          Rank  Runt
# Title
# Guardians of the Galaxy     1   121
# Prometheus                  2   124
# Split                       3   117
# Sing                        4   108
# Suicide Squad               5   123
# ...                       ...   ...
# Secret in Their Eyes      996   111
# Hostel: Part II           997    94
# Step Up 2: The Streets    998    98
# Search Party              999    93
# Nine Lives               1000    87
#
# [1000 rows x 2 columns]

# %%
run = mv.query("Runt >30 & Runt < 360")
run
# Out:
#                          Rank  Runt
# Title
# Guardians of the Galaxy     1   121
# Prometheus                  2   124
# Split                       3   117
# Sing                        4   108
# Suicide Squad               5   123
# ...                       ...   ...
# Secret in Their Eyes      996   111
# Hostel: Part II           997    94
# Step Up 2: The Streets    998    98
# Search Party              999    93
# Nine Lives               1000    87
#
# [1000 rows x 2 columns]
